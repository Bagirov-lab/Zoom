# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Packages</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Analyse" data-toc-modified-id="Analyse-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analyse</a></span><ul class="toc-item"><li><span><a href="#SP500-performance" data-toc-modified-id="SP500-performance-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>SP500 performance</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Packages

# %%
import pandas as pd

import plotly
import plotly.express as px

import sqlalchemy as sql

import pandas_datareader as pdr

# %% [markdown]
# ## Data

# %%
# Connect to server

Server = '194.87.248.66'
DB = 'Research'
Driver = 'SQL Server'
Name = 'Dony'
Password = 'PenisGaming1996'
Connection_str = f'mssql://{Name}:{Password}@{Server}/{DB}?driver={Driver}'

# Connect to SQL server
    
engine = sql.create_engine(Connection_str, echo=False)

Connection = engine.connect()

# %%
# Load data on SP500

DF_1 = pdr.get_data_yahoo('^GSPC')

# %% [markdown]
# ## Analyse

# %% [markdown]
# ### SP500 performance

# %%
output_file("datetime.html")

# create a new plot with a datetime axis type

fig = px.line(DF_1, y=['High','Low'],
              title='SP500, proxied from ^GSPC')
#fig.update_xaxes(
#    dtick="Y1",
#    tickformat="%M/%Y")

fig.update_xaxes(
    dtick="M3",
    tickformat="%b\n%Y",
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig.write_html("Graphs/Plot_1.html")
fig.write_image("Graphs/Plot_1.png")

fig.show()
# Out:
# <div>                            <div id="75b3b7bc-f707-4b06-a0a3-ca1f93d2c9d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75b3b7bc-f707-4b06-a0a3-ca1f93d2c9d2")) {                    Plotly.newPlot(                        "75b3b7bc-f707-4b06-a0a3-ca1f93d2c9d2",                        [{"hovertemplate": "variable=High<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "High", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "High", "showlegend": true, "type": "scattergl", "x": ["2016-05-04T00:00:00", "2016-05-05T00:00:00", "2016-05-06T00:00:00", "2016-05-09T00:00:00", "2016-05-10T00:00:00", "2016-05-11T00:00:00", "2016-05-12T00:00:00", "2016-05-13T00:00:00", "2016-05-16T00:00:00", "2016-05-17T00:00:00", "2016-05-1
# ...
